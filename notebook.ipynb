# %%
import pandas as pd

# %%
valor_y = pd.read_table('Arq02.txt')
valor_x = pd.read_table('Arq01.txt')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.title("f(x)=x cos(x) sen(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(valor_y)
plt.show()
